# %%
import pandas as pd
from statsmodels.tsa.stattools import adfuller

# %%
filepath = r"C:\Users\yetli\Documents\UDLAP\PR 2026\Eco II\Time-Series\Final\New\Consumo.csv"
consumo = pd.read_csv(filepath, encoding='latin-1')
consumo.plot()
# Out:
# <Axes: >

# %%
adfuller(consumo['Consumo'])
# Out:
# (np.float64(-0.7011900518215438),
#  np.float64(0.8464410467829654),
#  14,
#  382,
#  {'1%': np.float64(-3.4475850438570115),
#   '5%': np.float64(-2.869135963767125),
#   '10%': np.float64(-2.5708164748773332)},
#  np.float64(1213.2292961468468))
